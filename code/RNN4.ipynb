# %%
import numpy as np
# load data in train_test_data file. X_train, X_test, y_train, y_test in .npy format
X_train = np.load('../train_test_data/X_train.npy')
X_test = np.load('../train_test_data/X_test.npy')
y_train = np.load('../train_test_data/y_train.npy')
y_test = np.load('../train_test_data/y_test.npy')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()
model.add(layers.SimpleRNN(128, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dense(256, activation='leaky_relu'))
model.add(layers.Dense(13, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 128)               18048
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 13)                3341
#
# =================================================================
# Total params: 54413 (212.55 KB)
# Trainable params: 54413 (212.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [keras.callbacks.ModelCheckpoint("../models/RNN4.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
 
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"],)
 
model_history = model.fit(X_train,y_train, epochs= 10, validation_data=(X_test,y_test), callbacks=callbacks)
# Out:
# Epoch 1/10
# 151/151 [==============================] - 6s 19ms/step - loss: 1.0225 - sparse_categorical_accuracy: 0.6660 - val_loss: 0.7661 - val_sparse_categorical_accuracy: 0.7441
# Epoch 2/10
#   8/151 [>.............................] - ETA: 2s - loss: 0.5336 - sparse_categorical_accuracy: 0.8203
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 151/151 [==============================] - 2s 16ms/step - loss: 0.5364 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.7541 - val_sparse_categorical_accuracy: 0.7513
# Epoch 3/10
# 151/151 [==============================] - 2s 16ms/step - loss: 0.6029 - sparse_categorical_accuracy: 0.8032 - val_loss: 0.5941 - val_sparse_categorical_accuracy: 0.8179
# Epoch 4/10
# 151/151 [==============================] - 2s 16ms/step - loss: 0.3934 - sparse_categorical_accuracy: 0.8763 - val_loss: 0.4690 - val_sparse_categorical_accuracy: 0.8630
# Epoch 5/10
# 151/151 [==============================] - 2s 15ms/step - loss: 0.3187 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.5336 - val_sparse_categorical_accuracy: 0.8339
# Epoch 6/10
# 151/151 [==============================] - 3s 17ms/step - loss: 0.3329 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.4520 - val_sparse_categorical_accuracy: 0.8630
# Epoch 7/10
# 151/151 [==============================] - 3s 17ms/step - loss: 0.3449 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.4473 - val_sparse_categorical_accuracy: 0.8698
# Epoch 8/10
# 151/151 [==============================] - 2s 16ms/step - loss: 0.4021 - sparse_categorical_accuracy: 0.8801 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.7912
# Epoch 9/10
# 151/151 [==============================] - 3s 17ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.8973 - val_loss: 0.4573 - val_sparse_categorical_accuracy: 0.8747
# Epoch 10/10
# 151/151 [==============================] - 3s 17ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.4540 - val_sparse_categorical_accuracy: 0.8776

# %%
model = keras.models.load_model('../models/RNN4.h5')

train_loss, train_acc = model.evaluate(X_train,y_train)
test_loss, test_acc = model.evaluate(X_test,y_test)

print("Train accuracy", round(train_acc*100, 2),'%')
print("Train loss", train_loss)
print("Test accuracy", round(test_acc*100, 2),'%')
print("Test loss", test_loss)
# Out:
# 151/151 [==============================] - 1s 6ms/step - loss: 0.2302 - sparse_categorical_accuracy: 0.9442
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4473 - sparse_categorical_accuracy: 0.8698
# Train accuracy 94.42 %
# Train loss 0.23020358383655548
# Test accuracy 86.98 %
# Test loss 0.4472707509994507
