# %%
import numpy as np
# load data in train_test_data file. X_train, X_test, y_train, y_test in .npy format
X_train = np.load('../train_test_data/X_train.npy')
X_test = np.load('../train_test_data/X_test.npy')
y_train = np.load('../train_test_data/y_train.npy')
y_test = np.load('../train_test_data/y_test.npy')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()

model.add(layers.LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(13, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                19712
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 13)                1677
#
# =================================================================
# Total params: 29709 (116.05 KB)
# Trainable params: 29709 (116.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [keras.callbacks.ModelCheckpoint("../models/LSTM_bi.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
 
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"],)
 
model_history = model.fit(X_train,y_train, epochs= 10, validation_data=(X_test,y_test), callbacks=callbacks)
# Out:
# Epoch 1/10
# 151/151 [==============================] - 7s 28ms/step - loss: 0.9761 - sparse_categorical_accuracy: 0.7095 - val_loss: 0.4870 - val_sparse_categorical_accuracy: 0.8358
# Epoch 2/10
# 151/151 [==============================] - 4s 24ms/step - loss: 0.2443 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.2272 - val_sparse_categorical_accuracy: 0.9257
# Epoch 3/10
# 151/151 [==============================] - 4s 23ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.1031 - val_sparse_categorical_accuracy: 0.9709
# Epoch 4/10
# 151/151 [==============================] - 3s 23ms/step - loss: 0.1113 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1440 - val_sparse_categorical_accuracy: 0.9509
# Epoch 5/10
# 151/151 [==============================] - 4s 23ms/step - loss: 0.0619 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9733
# Epoch 6/10
# 151/151 [==============================] - 4s 25ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.0896 - val_sparse_categorical_accuracy: 0.9777
# Epoch 7/10
# 151/151 [==============================] - 4s 24ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.1099 - val_sparse_categorical_accuracy: 0.9626
# Epoch 8/10
# 151/151 [==============================] - 4s 24ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9747
# Epoch 9/10
# 151/151 [==============================] - 4s 24ms/step - loss: 0.0633 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.0782 - val_sparse_categorical_accuracy: 0.9781
# Epoch 10/10
# 151/151 [==============================] - 4s 25ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.0964 - val_sparse_categorical_accuracy: 0.9665

# %%
model = keras.models.load_model('../models/LSTM_bi.h5')

train_loss, train_acc = model.evaluate(X_train,y_train)
test_loss, test_acc = model.evaluate(X_test,y_test)

print("Train accuracy", round(train_acc*100, 2),'%')
print("Train loss", train_loss)
print("Test accuracy", round(test_acc*100, 2),'%')
print("Test loss", test_loss)
# Out:
# 151/151 [==============================] - 2s 8ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9948
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0782 - sparse_categorical_accuracy: 0.9781
# Train accuracy 99.48 %
# Train loss 0.024661505594849586
# Test accuracy 97.81 %
# Test loss 0.07824734598398209
