# %%
import numpy as np
# load data in train_test_data file. X_train, X_test, y_train, y_test in .npy format
X_train = np.load('../train_test_data/X_train.npy')
X_test = np.load('../train_test_data/X_test.npy')
y_train = np.load('../train_test_data/y_train.npy')
y_test = np.load('../train_test_data/y_test.npy')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()

model.add(layers.SimpleRNN(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dropout(0.2))

model.add(layers.SimpleRNN(64, return_sequences=True))
model.add(layers.Dropout(0.2)) 

model.add(layers.SimpleRNN(64))
model.add(layers.Dropout(0.2))


model.add(layers.Dense(128, activation='relu'))


model.add(layers.Dense(13, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 100, 64)           4928
#
#  dropout_3 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_4 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_4 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_5 (SimpleRNN)    (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 13)                1677
#
# =================================================================
# Total params: 31437 (122.80 KB)
# Trainable params: 31437 (122.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [keras.callbacks.ModelCheckpoint("../models/RNN2.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
 
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"],)
 
model_history = model.fit(X_train,y_train, epochs= 10, validation_data=(X_test,y_test), callbacks=callbacks)
# Out:
# Epoch 1/10
# 151/151 [==============================] - 10s 46ms/step - loss: 1.2978 - sparse_categorical_accuracy: 0.5294 - val_loss: 0.9409 - val_sparse_categorical_accuracy: 0.6134
# Epoch 2/10
#   3/151 [..............................] - ETA: 6s - loss: 0.8313 - sparse_categorical_accuracy: 0.6562
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 151/151 [==============================] - 6s 41ms/step - loss: 0.6994 - sparse_categorical_accuracy: 0.7143 - val_loss: 0.6363 - val_sparse_categorical_accuracy: 0.7858
# Epoch 3/10
# 151/151 [==============================] - 6s 42ms/step - loss: 0.6647 - sparse_categorical_accuracy: 0.7582 - val_loss: 1.0281 - val_sparse_categorical_accuracy: 0.6731
# Epoch 4/10
# 151/151 [==============================] - 6s 41ms/step - loss: 0.5657 - sparse_categorical_accuracy: 0.8009 - val_loss: 0.5090 - val_sparse_categorical_accuracy: 0.8431
# Epoch 5/10
# 151/151 [==============================] - 6s 40ms/step - loss: 0.5007 - sparse_categorical_accuracy: 0.8297 - val_loss: 0.4874 - val_sparse_categorical_accuracy: 0.8592
# Epoch 6/10
# 151/151 [==============================] - 6s 42ms/step - loss: 0.3946 - sparse_categorical_accuracy: 0.8769 - val_loss: 0.7628 - val_sparse_categorical_accuracy: 0.7644
# Epoch 7/10
# 151/151 [==============================] - 6s 42ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.8605 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.8703
# Epoch 8/10
# 151/151 [==============================] - 6s 40ms/step - loss: 0.4377 - sparse_categorical_accuracy: 0.8532 - val_loss: 0.3919 - val_sparse_categorical_accuracy: 0.8786
# Epoch 9/10
# 151/151 [==============================] - 6s 41ms/step - loss: 0.4711 - sparse_categorical_accuracy: 0.8272 - val_loss: 0.4536 - val_sparse_categorical_accuracy: 0.8533
# Epoch 10/10
# 151/151 [==============================] - 6s 41ms/step - loss: 0.3449 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.4183 - val_sparse_categorical_accuracy: 0.8669

# %%
model = keras.models.load_model('../models/RNN2.h5')

train_loss, train_acc = model.evaluate(X_train,y_train)
test_loss, test_acc = model.evaluate(X_test,y_test)

print("Train accuracy", round(train_acc*100, 2),'%')
print("Train loss", train_loss)
print("Test accuracy", round(test_acc*100, 2),'%')
print("Test loss", test_loss)
# Out:
# 151/151 [==============================] - 2s 10ms/step - loss: 0.2743 - sparse_categorical_accuracy: 0.9096
# 65/65 [==============================] - 1s 9ms/step - loss: 0.3919 - sparse_categorical_accuracy: 0.8786
# Train accuracy 90.96 %
# Train loss 0.2742977738380432
# Test accuracy 87.86 %
# Test loss 0.3918505012989044
