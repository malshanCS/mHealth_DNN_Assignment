# %%
import numpy as np
# load data in train_test_data file. X_train, X_test, y_train, y_test in .npy format
X_train = np.load('../train_test_data/X_train.npy')
X_test = np.load('../train_test_data/X_test.npy')
y_train = np.load('../train_test_data/y_train.npy')
y_test = np.load('../train_test_data/y_test.npy')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()

model.add(layers.Bidirectional(layers.SimpleRNN(64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dropout(0.2))

model.add(layers.Bidirectional(layers.SimpleRNN(64, return_sequences=True)))
model.add(layers.Dropout(0.2))

model.add(layers.Bidirectional(layers.SimpleRNN(64)))
model.add(layers.Dropout(0.2)) 


model.add(layers.Dense(128, activation='relu'))


model.add(layers.Dense(13, activation='softmax'))


model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 100, 128)          9856
#  al)
#
#  dropout (Dropout)           (None, 100, 128)          0
#
#  bidirectional_1 (Bidirecti  (None, 100, 128)          24704
#  onal)
#
#  dropout_1 (Dropout)         (None, 100, 128)          0
#
#  bidirectional_2 (Bidirecti  (None, 128)               24704
#  onal)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 13)                1677
#
# =================================================================
# Total params: 77453 (302.55 KB)
# Trainable params: 77453 (302.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [keras.callbacks.ModelCheckpoint("../models/RNN3.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
 
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"],)
 
model_history = model.fit(X_train,y_train, epochs= 10, validation_data=(X_test,y_test), callbacks=callbacks)
# Out:
# Epoch 1/10
# 151/151 [==============================] - 23s 90ms/step - loss: 1.1548 - sparse_categorical_accuracy: 0.5662 - val_loss: 0.6001 - val_sparse_categorical_accuracy: 0.7309
# Epoch 2/10
#   1/151 [..............................] - ETA: 9s - loss: 0.4529 - sparse_categorical_accuracy: 0.7812
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 151/151 [==============================] - 13s 89ms/step - loss: 0.5005 - sparse_categorical_accuracy: 0.7886 - val_loss: 0.3777 - val_sparse_categorical_accuracy: 0.8562
# Epoch 3/10
# 151/151 [==============================] - 13s 87ms/step - loss: 0.4331 - sparse_categorical_accuracy: 0.8438 - val_loss: 0.3199 - val_sparse_categorical_accuracy: 0.8810
# Epoch 4/10
# 151/151 [==============================] - 11s 73ms/step - loss: 0.3585 - sparse_categorical_accuracy: 0.8698 - val_loss: 0.4392 - val_sparse_categorical_accuracy: 0.8363
# Epoch 5/10
# 151/151 [==============================] - 9s 62ms/step - loss: 0.2737 - sparse_categorical_accuracy: 0.8998 - val_loss: 0.8344 - val_sparse_categorical_accuracy: 0.7785
# Epoch 6/10
# 151/151 [==============================] - 10s 65ms/step - loss: 0.2786 - sparse_categorical_accuracy: 0.8946 - val_loss: 0.1772 - val_sparse_categorical_accuracy: 0.9237
# Epoch 7/10
# 151/151 [==============================] - 10s 63ms/step - loss: 0.2199 - sparse_categorical_accuracy: 0.9173 - val_loss: 0.3776 - val_sparse_categorical_accuracy: 0.8592
# Epoch 8/10
# 151/151 [==============================] - 9s 62ms/step - loss: 0.2527 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.5154 - val_sparse_categorical_accuracy: 0.8082
# Epoch 9/10
# 151/151 [==============================] - 9s 62ms/step - loss: 0.2130 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.1687 - val_sparse_categorical_accuracy: 0.9320
# Epoch 10/10
# 151/151 [==============================] - 9s 61ms/step - loss: 0.1711 - sparse_categorical_accuracy: 0.9377 - val_loss: 0.3170 - val_sparse_categorical_accuracy: 0.8849

# %%
model = keras.models.load_model('../models/RNN3.h5')

train_loss, train_acc = model.evaluate(X_train,y_train)
test_loss, test_acc = model.evaluate(X_test,y_test)

print("Train accuracy", round(train_acc*100, 2),'%')
print("Train loss", train_loss)
print("Test accuracy", round(test_acc*100, 2),'%')
print("Test loss", test_loss)
# Out:
# 151/151 [==============================] - 3s 14ms/step - loss: 0.0934 - sparse_categorical_accuracy: 0.9661
# 65/65 [==============================] - 1s 14ms/step - loss: 0.1687 - sparse_categorical_accuracy: 0.9320
# Train accuracy 96.61 %
# Train loss 0.09338093549013138
# Test accuracy 93.2 %
# Test loss 0.16865535080432892
