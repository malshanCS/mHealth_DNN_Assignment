# %%
import numpy as np
# load data in train_test_data file. X_train, X_test, y_train, y_test in .npy format
X_train = np.load('../train_test_data/X_train.npy')
X_test = np.load('../train_test_data/X_test.npy')
y_train = np.load('../train_test_data/y_train.npy')
y_test = np.load('../train_test_data/y_test.npy')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()

model.add(layers.Bidirectional(layers.SimpleRNN(64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dropout(0.2))

model.add(layers.Bidirectional(layers.SimpleRNN(64, return_sequences=True)))
model.add(layers.Dropout(0.2))

model.add(layers.Bidirectional(layers.SimpleRNN(64)))
model.add(layers.Dropout(0.2)) 


model.add(layers.Dense(128, activation='relu'))


model.add(layers.Dense(13, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 100, 128)          9856
#  al)
#
#  dropout (Dropout)           (None, 100, 128)          0
#
#  bidirectional_1 (Bidirecti  (None, 100, 128)          24704
#  onal)
#
#  dropout_1 (Dropout)         (None, 100, 128)          0
#
#  bidirectional_2 (Bidirecti  (None, 128)               24704
#  onal)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 13)                1677
#
# =================================================================
# Total params: 77453 (302.55 KB)
# Trainable params: 77453 (302.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [keras.callbacks.ModelCheckpoint("../models/RNN3.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
 
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"],)
 
model_history = model.fit(X_train,y_train, epochs= 10, validation_data=(X_test,y_test), callbacks=callbacks)
# Out:
# Epoch 1/10
# 151/151 [==============================] - 20s 92ms/step - loss: 1.1014 - sparse_categorical_accuracy: 0.5885 - val_loss: 0.6090 - val_sparse_categorical_accuracy: 0.7305
# Epoch 2/10
#   1/151 [..............................] - ETA: 15s - loss: 0.9474 - sparse_categorical_accuracy: 0.6875
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 151/151 [==============================] - 10s 66ms/step - loss: 0.4865 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.4192 - val_sparse_categorical_accuracy: 0.8222
# Epoch 3/10
# 151/151 [==============================] - 10s 63ms/step - loss: 0.3246 - sparse_categorical_accuracy: 0.8726 - val_loss: 0.4218 - val_sparse_categorical_accuracy: 0.8324
# Epoch 4/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.2787 - sparse_categorical_accuracy: 0.8969 - val_loss: 0.2270 - val_sparse_categorical_accuracy: 0.9024
# Epoch 5/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.2885 - sparse_categorical_accuracy: 0.8953 - val_loss: 0.2581 - val_sparse_categorical_accuracy: 0.9004
# Epoch 6/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.1858 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.5994 - val_sparse_categorical_accuracy: 0.8577
# Epoch 7/10
# 151/151 [==============================] - 10s 65ms/step - loss: 0.2624 - sparse_categorical_accuracy: 0.9030 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.8694
# Epoch 8/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.1825 - val_sparse_categorical_accuracy: 0.9296
# Epoch 9/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.1601 - val_sparse_categorical_accuracy: 0.9339
# Epoch 10/10
# 151/151 [==============================] - 10s 64ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.8853 - val_loss: 0.4568 - val_sparse_categorical_accuracy: 0.8606

# %%
model = keras.models.load_model('../models/RNN3.h5')

train_loss, train_acc = model.evaluate(X_train,y_train)
test_loss, test_acc = model.evaluate(X_test,y_test)

print("Train accuracy", round(train_acc*100, 2),'%')
print("Train loss", train_loss)
print("Test accuracy", round(test_acc*100, 2),'%')
print("Test loss", test_loss)
# Out:
# 151/151 [==============================] - 4s 20ms/step - loss: 0.0806 - sparse_categorical_accuracy: 0.9738
# 65/65 [==============================] - 1s 14ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9339
# Train accuracy 97.38 %
# Train loss 0.08055295050144196
# Test accuracy 93.39 %
# Test loss 0.16007545590400696
